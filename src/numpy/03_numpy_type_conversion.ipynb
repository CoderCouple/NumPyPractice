# %% [markdown]
# # Numpy type Conversion
#
# You can explicitly convert or cast an array from one data type to another using ndarray’s **astype** method:
# In this example, integers were cast to floating point. If I cast some floating-point numbers to be of integer data type, the decimal part will be truncated:

# %%
import numpy as np

data = np.array([1, 2, 3])
print(data)
# Out:
# [1 2 3]

# %%
data.dtype
# Out:
# dtype('int64')

# %%
data = data.astype(np.float32)
print(data)
# Out:
# [1. 2. 3.]

# %%
num_string = np.array(["1.5","3.6","2.1"], dtype=np.str_)
print(num_string)
print(num_string.dtype)
# Out:
# ['1.5' '3.6' '2.1']
# <U3

# %%
num = num_string.astype(np.float32)
print(num)
# Out:
# [1.5 3.6 2.1]
