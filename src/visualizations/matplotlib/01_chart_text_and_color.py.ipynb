# %%
from symbol import factor

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.plot(2,2,'.')
plt.title("Text and Color", family="Arial", size=24, color="blue", weight="bold", ha="center")
plt.xlabel('x', color="blue", weight="bold", size=15, family="Arial")
plt.ylabel('y', color = "red", weight="bold", size=15, family="Arial")
# Out:
# Text(0, 0.5, 'y')
