# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Creating random arrays
a = np.random.randint(1, 100, 10)
b = np.random.randint(1, 100, 10)
x  = np.random.randint(1, 100, 10)
y = np.random.randint(1, 100, 10)

# %%
print(a,b,x,y)
# Out:
# [53 46  4 16 67 92 57 72 29 19] [92 71 37 76  4 60 70 57  5 60] [86 84 43 69 50 58  9 41 74 69] [62 78 80 79 48 34 10 47 53 63]

# %%
# creating a figure
fig = plt.figure()
ax = plt.subplot()
ax.plot(x,y,'.')

# %%
fig = plt.figure()
ax1 = plt.subplot(2,2,1)
ax1.plot(x,y,'.')

ax2 = plt.subplot(2,2,2)
ax2.plot(x,a,'.')

ax3 = plt.subplot(2,2,3)
ax3.plot(y,b,'.')

ax4 = plt.subplot(2,2,4)
ax4.plot(x,y,'.')
