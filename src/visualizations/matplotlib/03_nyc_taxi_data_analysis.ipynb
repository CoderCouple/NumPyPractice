# %% [markdown]
# # NYC Taxi Data Analysis

# %%
# %matplotlib widget
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
plt.ion()

plt.get_backend()
plt.plot(np.random.randn(100).cumsum())
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
df1 = pd.read_csv("../../../data/matplotlib/Yellow Taxi Trips - Week 1.csv")
df2 = pd.read_csv("../../../data/matplotlib/Yellow Taxi Trips - Week 2.csv")
df3 = pd.read_csv("../../../data/matplotlib/Yellow Taxi Trips - Week 3.csv")
df4 = pd.read_csv("../../../data/matplotlib/Yellow Taxi Trips - Week 4.csv")
df5 = pd.read_csv("../../../data/matplotlib/Yellow Taxi Trips - Week 5.csv")
df_full = pd.concat([df1,df2,df3,df4,df5])
df_full.head()
# Out:
#        ID Pickup_Date  Week_No  Passenger_Count  Trip_Distance  Tip_Amount  \
# 0  418880  07/01/2022        1                1          17.45         0.0
# 1  266865  05/01/2022        1                1          18.25         0.0
# 2  227117  04/01/2022        1                1          18.35         0.0
# 3  193883  04/01/2022        1                1          17.70         0.0
# 4  193349  04/01/2022        1                1          16.01         0.0
#
#    Total_Amount  Airport_Fee Payment_Type Rate_Code
# 0         79.05          0.0  Credit card    Newark
# 1         84.05          0.0         Cash    Newark
# 2         84.05          0.0  Credit card    Newark
# 3         78.05          0.0  Credit card    Newark
# 4         75.05          0.0         Cash    Newark

# %%
df_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2367338 entries, 0 to 177534
# Data columns (total 10 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   ID               int64
#  1   Pickup_Date      object
#  2   Week_No          int64
#  3   Passenger_Count  int64
#  4   Trip_Distance    float64
#  5   Tip_Amount       float64
#  6   Total_Amount     float64
#  7   Airport_Fee      float64
#  8   Payment_Type     object
#  9   Rate_Code        object
# dtypes: float64(4), int64(3), object(3)
# memory usage: 198.7+ MB

# %%
df_full.describe()
# Out:
#                  ID       Week_No  Passenger_Count  Trip_Distance  \
# count  2.367338e+06  2.367338e+06     2.367338e+06   2.367338e+06
# mean   1.196525e+06  2.775018e+00     1.391399e+00   3.107514e+00
# std    6.905042e+05  1.241424e+00     9.849662e-01   4.309897e+00
# min    1.000000e+00  1.000000e+00     0.000000e+00   0.000000e+00
# 25%    5.985912e+05  2.000000e+00     1.000000e+00   1.040000e+00
# 50%    1.196656e+06  3.000000e+00     1.000000e+00   1.720000e+00
# 75%    1.794466e+06  4.000000e+00     1.000000e+00   3.100000e+00
# max    2.392428e+06  5.000000e+00     9.000000e+00   6.510000e+02
#
#          Tip_Amount  Total_Amount   Airport_Fee
# count  2.367338e+06  2.367338e+06  2.367338e+06
# mean   2.393453e+00  1.906640e+01  8.330771e-02
# std    2.836869e+00  1.495028e+01  3.117603e-01
# min    0.000000e+00  1.000000e-02  0.000000e+00
# 25%    9.600000e-01  1.130000e+01  0.000000e+00
# 50%    2.000000e+00  1.430000e+01  0.000000e+00
# ...

# %%
#change date format
df_full["Pickup_Date"] = pd.to_datetime(df_full["Pickup_Date"], format="%d/%m/%Y")
df_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2367338 entries, 0 to 177534
# Data columns (total 10 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   ID               int64
#  1   Pickup_Date      datetime64[ns]
#  2   Week_No          int64
#  3   Passenger_Count  int64
#  4   Trip_Distance    float64
#  5   Tip_Amount       float64
#  6   Total_Amount     float64
#  7   Airport_Fee      float64
#  8   Payment_Type     object
#  9   Rate_Code        object
# dtypes: datetime64[ns](1), float64(4), int64(3), object(2)
# memory usage: 198.7+ MB

# %%
df_full.head()
trips = df_full.groupby(by='Pickup_Date', as_index=False)["ID"].count()
trips.head()
# Out:
#   Pickup_Date     ID
# 0  2022-01-01  60535
# 1  2022-01-02  56692
# 2  2022-01-03  70059
# 3  2022-01-04  72209
# 4  2022-01-05  72176

# %%
trips.rename(columns={"ID": "Trips"}, inplace=True)
trips.head()
# Out:
#   Pickup_Date  Trips
# 0  2022-01-01  60535
# 1  2022-01-02  56692
# 2  2022-01-03  70059
# 3  2022-01-04  72209
# 4  2022-01-05  72176

# %%
fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(trips["Pickup_Date"], trips["Trips"])
plt.xticks(rotation=45)
plt.yticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
